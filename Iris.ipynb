# %% [markdown]
# <a href="https://colab.research.google.com/github/gadosanjos/Machine-Learning-Repository/blob/main/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the necessary modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression

# Read in the file fg_attempt.csv
iris_dataset = pd.read_csv('iris_data.csv')

print (f"{iris_dataset.shape}")
# Out:
# (150, 5)

# %%
x1Name = 'petal_length'
x2Name = 'petal_width'
x3Name = 'sepal_length'
x4Name = 'sepal_width'
iris_dataset.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %%
# Create a dataframe X containing 2 features
X = iris_dataset[[x1Name,x2Name]]
X.head(2)
# Out:
#    petal_length  petal_width
# 0           1.4          0.2
# 1           1.4          0.2

# %%
# Create a dataframe y containing 'class'
y = iris_dataset[['class']]
y.head(2)
# Out:
#          class
# 0  Iris-setosa
# 1  Iris-setosa

# %%
p = sns.scatterplot(data=iris_dataset, x=x1Name, y=x2Name, hue='class', style='class')

# %%
#Not as usefull so the pair x3 and x4 will not be used
p2 = sns.scatterplot(data=iris_dataset, x=x3Name, y=x4Name, hue='class', style='class')

# %%
# Flatten y into an array
y = np.ravel(y)

# %%
# Initialize a LogisticRegression() model
logisticModel = LogisticRegression()

# %%
# Fit the model
logisticModel.fit(X, y)
# Out:
# LogisticRegression()

# %%
# Input feature values for a sample instance
x1 = float(input())
x2 = float(input())
# Out:
# 3
# 6

# %%
XNew = pd.DataFrame({'petal_length':[x1], 'petal_width':[x2]})

# %%
# Predict the outcome from the new data
pred = logisticModel.predict(XNew)
print(pred)
# Out:
# ['Iris-virginica']

# %%
# Determine the accuracy of the model logisticModel
score = logisticModel.score(X, y)
print(f"{score:.2f}")
# Out:
# 0.97
